# %% [markdown]
# # スクレイピングとは
# WEB上のデータを収集（クローリングと言います）し、特定の情報を抽出することです。
# 正確に言うとWEBスクレイピング、となります。
#
# <br>
#
# ## 情報の特定方法
# 1. HTMLのタグ名で特定
# 1. CSSセレクタで特定
# 1. XPATHで特定
#
# <br>
#
# ## HTMLのタグとは
#
# ホームページ（WEBページ)は、HTMLを使って作られています。
# HTMLとは、Hyper Text Markup Language(ハイパーテキスト・マークアップランゲージ）の略で、
# タグを使って、HTML文書の構造（ここは見出しでここからは段落など）を指定します。
#
# <br>
#
# ## CSSのセレクタとは
#
# CSSとは、Cascading Style Sheets（カスケード・スタイルシート）とは、HTML文書の装飾や
# レイアウトをつくるための言語です。セレクタでどの要素にデザインをするか指定します。
#
# <br>
#
# ## XPATHとは
# XPATH(Xml Path Language)とは、XML形式の文書から、特定の部分を指定して抽出するための言語です。
# <br>
# ※HTML形式の文書にも対応しています。
# <br>
# <br>
#
# ## findとfind_all
# findメソッドを利用することで、任意のidやclass属性を
# 指定し要素を見つけることが出来ます。
# findでは初めにヒットした1件しか取得されません。
#
# find_allを使うと、複数の要素（タグ）を一気に取得する
# ことが出来ます。
# <br>
#
# **例**
# <br>
# - soup.find("body")
# - soup.find_all("a")
# - soup.find_all('タグ名’, class_="クラス名")
# <br>
# 注意点：classは予約語のため、class=“クラス名”ではなく、
# class_=“クラス名”とするところに注意しましょう。
#
#
# ## select_oneとselect
# CSSセレクタを使って取得をする場合は、select_oneとselectを用います。
# findやfind_allと同じく、select_oneがヒットした件数の先頭1件のみ
# 取得し、selectは全て取得します。
#
# **例**
# <br>
# - soup.select_one('セレクタ名')
# - soup.select('セレクタ名')
# <br>
# <br>
#
# ## スクレイピング・クローリングを行うにあたって
#
# スクレイピングを行う前に、確認するべき点や、作業中に気を付ける必要がある点がいくつかありますので説明します。
# <br>
# <br>
# １）APIが存在するかどうか
# <br>
# APIを提供しているサービスがあればそちらを使い、データを取得しましょう。
# それでも、十分なデータが得られない等の問題があるのであればスクレイピングを検討します。
# <br>
# <br>
# ２）取得後のデータの用途に関して
# 取得後のデータを使う場合には、注意が必要です。
# 取得先のデータは自分以外の著作物にあたり、著作権法に抵触しないように考慮する必要があるためです。
# <br>
# 特に問題になりやすい権利として以下の3つが挙げられます。
# <br>
# <br>
# - 複製権:
# 複製権は、著作権に含まれる権利のひとつで、著作権法第21条で規定されています。（第21条「著作者は、その著作物を複製する権利を専有する。」）
# 複製とは、作品を複写したり、録画・録音したり、印刷や写真にしたり、模写（書き写し）したりすること、そしてスキャナーなどにより電子的に読み取ること、また保管することなどを言います。
# <br>
# <br>
# - 翻案権:
# 翻訳権・翻案権は、著作権法第二十七条に規定されている著作財産権です。
# 第二十七条では｢著作者は、その著作物を翻訳し、編曲し、若しくは変形し、又は脚色し、映画化し、その他翻案する権利を専有する｣（『社団法人著作権情報センター』より）と明記されています。
# 反対に見ると、これらを著作者の許諾なしに行うと、著作権の侵害になるということです。
# <br>
# <br>
# - 公衆送信権:
# 公衆送信権は、著作権法第二十三条において規定される著作財産権です。「著作者は、公衆送信されるその著作物を受信装置を用いて公に伝達する権利を占有する。」と明記されています。
# <br>
# <br>
# また上記を注意しながら、実際にスクレイピングを行う際に、書いたコードによってサーバに負荷がかからないようにしましょう。
# 過度なアクセスはサーバに負担をかけてしまい攻撃だとみなされてしまい、最悪の場合一定期間サービスを利用できなくなってしまう可能性があります。
# さらには、システムにアクセス障害が発生し、利用者の一人が逮捕された事件もありますので、常識の範囲内での使用してください。
# <br>
# <br>
#
# [岡崎市立中央図書館事件](https://ja.wikipedia.org/wiki/%E5%B2%A1%E5%B4%8E%E5%B8%82%E7%AB%8B%E4%B8%AD%E5%A4%AE%E5%9B%B3%E6%9B%B8%E9%A4%A8%E4%BA%8B%E4%BB%B6)
#
#
# <br>
# <br>
#
# ## Google Chromeの「開発者ツール」を使って、WEBページからCSSセレクタかXPathを取得してみる。
#
# （実演）

# %% [markdown]
# # ハンズオンパート
# ## 一緒に手を動かしてみましょう！
# ### CSSセレクタでAI Academyのコースをスクレイピングしてみましょう。

# %%
# 必要になるライブラリをここでまとめてインストールしておきます。
# !pip install lxml bs4 requests selenium
# Out:
# Requirement already satisfied: lxml in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (4.3.1)
# Requirement already satisfied: bs4 in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: requests in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (2.20.0)
# Requirement already satisfied: selenium in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (3.141.0)
# Requirement already satisfied: beautifulsoup4 in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (from bs4) (4.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (from requests) (2018.8.24)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (from requests) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (from requests) (2.7)
# Requirement already satisfied: soupsieve>=1.2 in ./.pyenv/versions/3.7.1/lib/python3.7/site-packages (from beautifulsoup4->bs4) (1.7.3)
# You are using pip version 18.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup as bs
import requests
import lxml

url = 'https://aiacademy.jp/texts/'    # 取得するWEBページを記載する
r = requests.get(url)    # requestsを使って、WEBページからデータを取得する
soup = bs(r.text, 'lxml')    # lxmlを使って取得したデータを分析する

# CSSセレクタで特定する場合、以下を含む場合は、変更が必要になるので注意
# 例　li:nth-child(1) -> li:nth-of-type(1)

scraped = soup.select("body > section > div > div > div.col-md-4 > div.subjects > ul > li:nth-of-type(1) > a")    # 分析結果から、CSSセレクタで特定する
for s in scraped:
    print(s.text)    # テキストを表示する
# Out:
# 目的別コース

# %% [markdown]
# ## 一緒に手を動かしてみましょう！
# ### 次に、XPATHでも同じ箇所をスクレイピングしてみましょう。

# %%
import requests
import lxml.html

url = "https://aiacademy.jp/texts/"
r = requests.get(url)
html = lxml.html.fromstring(r.text)
scraped = html.xpath("/html/body/section/div/div/div[1]/div[1]/ul/li[1]/a")    # 分析結果から、XPATHで特定する
for s in scraped:
    print(s.text)
# Out:
# 目的別コース

# %% [markdown]
# ## 一緒に手を動かしてみましょう！
# ### 最後にHTMLタグでコース一覧をスクレイピングしてみましょう。

# %%
from bs4 import BeautifulSoup as bs
import requests
import lxml

url = 'https://aiacademy.jp/texts/'    # 取得するWEBページを記載する
r = requests.get(url)    # requestsを使って、WEBページからデータを取得する
soup = bs(r.text, 'lxml')    # lxmlを使って取得したデータを分析する

scraped = soup.find(class_="nav nav-tabs tabs-left").find_all("li")    # 分析結果から、HTMLタグで特定する
for s in scraped[5:60]:
     print(s.text)    # テキストを表示する
# Out:
# 機械学習プログラミング体験編
#
# 深層学習プログラミング体験編
#
# Python プログラミング入門編
#
# Python プログラミング中級編
#
# Pythonデータ分析入門編
#
# Python開発環境編
#
# 人工知能概論編
#
# Deep learning入門編
#
# 機械学習プログラミング入門編
#
# 機械学習プログラミング中級編
#
# 機械学習アルゴリズム編
#
# データ解析 実践編
#
# データ前処理編
#
# ディープラーニング・ライブラリ入門編
#
# Deep learning (実装編)
#
# 機械学習に必要な数学編
#
# 統計学編
#
# 機械学習アルゴリズム(理論編)
#
# 自然言語処理編
#
# 画像認識編
#
# クラウド入門編
#
# コマンドライン基礎編
#
# SQL入門編
#
# SQL中級編
#
# WEBスクレイピング編
#
# Webアプリケーション開発編
#
# R言語文法速習

# %% [markdown]
# # Seleniumとは
#
# SeleniumはWebブラウザで行うクリック操作やキーボード入力などをプログラム上から自動で操作できるようにしたライブラリで
# <br>
# Chrome DriverはChromeブラウザをプログラムで動かす為のドライバーです。
# <br>
# この2つを使うことで、SeleniumでChromeブラウザを操作してログインすることが可能です。
# <br>
# またこの2つを組み合わせて使うことで、次のことが可能になります。
# <br>
# <br>
# - スクレイピング
# - ブラウザの自動操作(次へボタンや購入ボタンなどを自動で押すなど）
# - システムの自動テスト
# - 非同期サイトのスクレイピング
# <br>
# <br>
#
# Chrome Driverのインストールは下記リンクから飛べます。
# <br>
# <br>
# [Chrome Driver インストールリンク](http://chromedriver.chromium.org/downloads)
# <br>
# その後、『Latest Release: ChromeDriver 2.42』と書かれた部分をクリックし、zipファイルをインストール&解凍してください。
# <br>
# ※テキストに書かれたバージョンと異なる場合がございます。
# 常に、Chrome Driverは常に最新のものをご利用ください。
# <br>
# バージョンが以前のものを使うと動作しない可能性があります。

# %% [markdown]
# # ハンズオンパート
# ## 一緒に手を動かしてみましょう！
# ### Twitterを任意のキーワードで検索し、キーワードを含むツイートを取得してみましょう。

# %%
from time import sleep
import os
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import lxml

current_path = os.getcwd()    # カレントディレクトリを取得
driver_path = current_path + "/chromedriver"    # chromedriverのパスを作成
driver = webdriver.Chrome(executable_path=driver_path)    # パスを指定して、selenium起動（ウインドウが開かれます）
search_url = "https://twitter.com/search?f=tweets&vertical=default&q=%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92&src=typd"
driver.get(search_url)    #  指定したURLを開く
for i in range(10):     # 引数の数だけ画面をスクロールする
    driver.execute_script(
        "window.scrollTo(0, document.body.scrollHeight);")
    sleep(1)
    
html_source = driver.page_source    # WEBページのソースを取得
soup = bs(html_source, "lxml")
souped = soup.find_all("p", class_="tweet-text")
print(len(souped))

for s in souped:
    print("======================================")
    print(s.text)
    print("======================================")
    print("")
# Out:
# 220
# ======================================
# 神奈川県民だけど人生初くらいの勢いで二宮町pic.twitter.com/PAiE4AH7Gx
# ======================================
#
# ======================================
# 2チーム目「研究内容の改竄防止に関する提案」
# 偽装データや異常値をなくすために機械学習を用いる
# 調査依頼者は調査の貢献度によってETHを受け取る
# インセンティブ設計にはEMアルゴリズムというものを使う
# ======================================
#
# ======================================
# AWS SageMakerとAPI-Gateway、lambdaを使ったサーバレスな機械学習アプリケーションを作ってみた。
# https://qiita.com/kurakura0916/items/5d6e9254e5c654e098a7 …
# ======================================
#
# ======================================
# Kinect等を使用してフロアの客の動きや体温を検出、それらのデータからGoogleで流すべき映像と曲をyoutubeから選別、曲間はMixではなく機械学習によるモーフィング。
# こんな事をやってみたいです。
# ======================================
#
# ======================================
# 1000RT：【すげー】実在しない人物の顔をワンタッチで生成できるウェブサイトが誕生
# http://news.livedoor.com/article/detail/16033633/ …
#
# 一見すると本物の顔写真と見分けがつきませんが、これらの画像は全て機械学習アルゴリズムが生成した架… pic.twitter.com/ikSTQBlNL8
# ======================================
#
# ======================================
# AIとか機械学習の一端に触れてみるテスト(数学苦手すぎて頭悪い私)
# ======================================
#
# ======================================
# 次は GCPUG OSAKA オーガナイザーの大原さんによる「30分でわかるGCPを使った機械学習システムの構築」です！
# #gcpja #gcpug #tokushima #gdgshikokupic.twitter.com/XGGPAQcuB7
# ======================================
#
# ======================================
# 機械学習システムのアーキテクチャアラカルト #api # https://www.slideshare.net/BrainPad/ss-131876455 … @SlideShareさんから
# ======================================
#
# ======================================
# 人工知能に興味がある方は是非ご覧ください。 #はてなブログ
# Python～機械学習入門～ - 日常・趣味を語る
# https://salieri.hatenablog.com/entry/2019/02/17/Python%EF%BD%9E%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E5%85%A5%E9%96%80%EF%BD%9E …
# ======================================
#
# ======================================
# #gcpug tokushima
# 「GCPを使った機械学習システム構築の一式を説明する」株式会社ビヨンド 大原 裕也さん（GCPUG大阪）はじまりました
# ======================================
#
# ======================================
# ACML2019: Call for papershttp://dlvr.it/Qz4F2k
# ======================================
#
# ======================================
# これは機械学習で生成されたら顔だそうです。
#
# リロードの度に違う顔が出るのて、このTwitterからリンクした人はそれぞれ別の顔を見る事になるんですね。
#
# ちなみに一回目は口の中がレインボー色の宇宙みたいになってる出来損ないの顔でちょっとドキっとしました。
#
# https://thispersondoesnotexist.com/
# ======================================
#
# ======================================
# 材料開発にAI革命 金属など 「職人技」より効率的 - 日本経済新聞
# https://www.nikkei.com/article/DGKKZO4132022015022019MY1000/ … #人工知能 #機械学習 #AI
# ======================================
#
# ======================================
# 機械学習と統計学は使い分けが必要なんだな〜と理解
# ラッキーなのは、統計学に精通してそうな教授が未来大にいること
# ======================================
#
# ======================================
# 多分今集めてるデータ普通に売れる気がするし、次転職する時は実績として有効に使おう。もう機械学習も飽きてしまって内容のアップデートとかやる気しないけど
# ======================================
#
# ======================================
# これ見てるとpandasでtable見ながら機械学習モデル組んでる時の気分になる
# ======================================
#
# ======================================
# 機械学習と統計学の違いがわかった！
# https://qiita.com/KanNishida/items/8ab8553b17cb57e772d6 …
# ======================================
#
# ======================================
# Google、データサイエンス、機械学習のKaggle買収を確認 (TechCrunch Japan) #NewsPickshttp://jp.techcrunch.com/2017/03/09/20170308google-confirms-its-acquisition-of-data-science-community-kaggle/ …
# ======================================
#
# ======================================
# AWS SageMakerとAPI Gateway、Lambdaで作るサーバレスな機械学習アプリケーション https://qiita.com/kurakura0916/items/5d6e9254e5c654e098a7 … #Qiita
# ======================================
#
# ======================================
# 次はPython勉強しようと思ってる
# 目的は
# ・機械学習を勉強するため
# 目標
# ・CodeScriptのイベントに参加する
# ・Paizaの評価制で企業訪問する
# ツール
# ・Progate
# ・Paiza
# 期間: 1ヶ月
# ======================================
#
# ======================================
# AIとか機械学習とかトレンドですね。
# わたしもしばらくPythonistaだったのでうらやましいですね。
# ======================================
#
# ======================================
# レベル高い！
# ======================================
#
# ======================================
# 各社、機械学習に投資した分は回収できたんですかね(定期ツイート)。Recruit Institute of Technology ってあったなあって見てみたら、Megagon Labsって名前になってた。Megagon=百万角形か。まあRecruitって入隊させるとか採用するとか新規の人って意味だからね、意味不明すぎる名前だ。
# ======================================
#
# ======================================
# 米スタートアップ、量子コンピューターで機械学習の実行に成功
# http://www.technologyreview.jp/s/67334/a-startup-uses-quantum-computing-to-boost-machine-learning/ …
# ======================================
#
# ======================================
# DeepLearningモデル
# http://bit.ly/2q6R9CA
# #深層学習 #人工知能 #機械学習 #ニューラルネットワーク #NVIDIA
# #TESLA
# ======================================
#
# ======================================
# 500RT：【すげー】実在しない人物の顔をワンタッチで生成できるウェブサイトが誕生
# http://news.livedoor.com/article/detail/16033633/ …
#
# 一見すると本物の顔写真と見分けがつきませんが、これらの画像は全て機械学習アルゴリズムが生成した架空の人物。 pic.twitter.com/H3PwNKLXLG
# ======================================
#
# ======================================
# Day38
#
# 今日もProgateとPythonと機械学習です。
# ProgateはRuby on Railsコースをちょい進めて、明日は道場コースとかやる予定です。
# Pythonはエスケープ文字や改行の方法とかを学びました。
# 機械学習はpandasを学びました。データの結合とか連結のやり方をちょっと学んだ感じスね。。
#
# #100DaysOfCode
# ======================================
#
# ======================================
# 過去記事紹介：エヌビディアが機械学習の「パラダイムを覆す」新手法を研究中（無料会員閲覧可能） http://ow.ly/ibNL30nGhMz
# ======================================
#
# ======================================
# 機械学習はもはや理論がわからなくても、それらしいものが誰でも作れる時代なんだなぁ。
# ただ中身がわからないブラックボックスを臨床応用するのは怖い気もする。
# ======================================
#
# ======================================
# https://thispersondoesnotexist.com/
# 機械学習によって生成された顔
# ======================================
#
# ======================================
# しかし，何も起こらない！https://twitter.com/NN17974816/status/1091328537087303680 …
# ======================================
#
# ======================================
# 画像の機械学習、冗談じゃないぐらい時間がかかる
# ======================================
#
# ======================================
# 「旦那捨てたい」にＡＩが神回答！ 機械学習で人工知能の世界がとんでもないことに！ http://goo.gl/pfQs16
# ======================================
#
# ======================================
# ちょっと分野や対象が変わるとコミュニティが断絶するのは機械学習に限らずだし、データ分析をする人とそれ以外の人の溝は機械学習セグメント内での断絶より遥かに深いのでこの比喩としては荒川ぐらいでいいと思う https://twitter.com/TJO_datasci/status/1096798343521390593 …
# ======================================
#
# ======================================
# アップルの機械学習、AIを振り回し、タジタジにさせてますね！さすがです！笑 ^_^
# ======================================
#
# ======================================
# 機械学習アルゴリズムが生成した架空の人物と全く同じ顔の人 #いろいろな人
# ======================================
#
# ======================================
# 機械学習でありとあらゆる格闘技を習得した肉体言語AIロボとかもう出てきてもおかしくない
# ======================================
#
# ======================================
# ディープラーニングとか機械学習の仕組みをPythonで学習出来る本や、サイトあるけど興味がない。
# それより、公開されているAIのAPIを使ってアプリにどう組み込んで、どんなサービス作れるかに対して考えることに時間を使いたい！その方が価値を出せると思う。
# ======================================
#
# ======================================
# AIでアニメ自動彩色 奈良先端大チーム、製作会社と共同開発（毎日新聞） - Yahoo!ニュース
# https://headlines.yahoo.co.jp/hl?a=20190217-00000017-mai-sctch … #人工知能 #機械学習 #AI
# ======================================
#
# ======================================
# 【徳島】GCPUG Tokushima #4 機械学習 Machine Learning #gupug
# TensorFlow for Poets | Qwiklabs を使用したハンズオン中ですhttps://google.qwiklabs.com/focuses/1095?catalog_rank=%7B%22rank%22%3A5%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=2016910 …
# ======================================
#
# ======================================
# ライブドアニュース
#
# 実在しない人物の顔をワンタッチで生成できるウェブサイトが誕生
# http://news.livedoor.com/article/detail/16033633/ …
#
# 一見すると本物の顔写真と見分けがつきませんが、これらの画像は全て機械学習アルゴリズムが生成した架空の人物。 pic.twitter.com/Yk3cvXq2ll
# ======================================
#
# ======================================
# 簡単な自己紹介をしておきます
# ・エンジニアを目指して勉強中の高校生
# ・Windowsユーザー
# ・ある程度書ける言語:Python
# ・勉強中の言語:Ruby, Java, JS, PHP, HTML/CSS
# ・使用エディタ:PyCharm, Atom
# ・Android使用アプリ:QPython,Pydroid3,Dcoder
# ・興味のある分野:機械学習, Webアプリ開発, etc.
# ======================================
#
# ======================================
# なるほどです！機械学習は全然なので勉強になります！
#
# これって多分、物体のBounding Boxは取れるけど、z座標(カメラからの距離)って取れませんよね？もし取れたらそのままARの座標系に変換すれば線を描けると思います。
#
# 取れなかったら実装が早いのはマーカーですかね。。
# ======================================
#
# ======================================
# 耳の老化は認知症の発症を早めるとも言われています。
#
# あなたの耳は「老人耳」、「中年耳」、「若者耳」？http://bit.ly/2QK1Wz9
# ======================================
#
# ======================================
# 機械学習で関数解析ガチ本ないんで『ヒルベルト空間と量子力学 改訂増補版』衝動買いした
# ======================================
#
# ======================================
# 最近は裏で従業員にお金払って操作してる人がいて、株価の下落で儲けようとしているんじゃないかなって思ってる(でなければ理解不能)。https://lin.ee/1gGXhg?utm_source=line&utm_medium=share&utm_campaign=none …
# ======================================
#
# ======================================
# 【すげー】実在しない人物の顔をワンタッチで生成できるウェブサイトが誕生
# http://news.livedoor.com/article/detail/16033633/ …
#
# 一見すると本物の顔写真と見分けがつきませんが、これらの画像は全て機械学習アルゴリズムが生成した架空の人物。 pic.twitter.com/Dti1zoVkbb
# ======================================
#
# ======================================
# 何故かわや氏が機械学習…また詳しく聞かせてくださいなww
# ぴちょんは可愛いなww
#
# ちなみに、iPhoneで「ぱいそん」って入力すると、ちゃんと「Python」って出てくるよ
# ======================================
#
# ======================================
# 別にAIの機械学習でも面白い作品なら面白いって思うぞ
# 作品読むときにいちいち作者の経験や感情なんて意識しないし
# ======================================
#
# ======================================
# WEB実装と機械学習は完全に別物なので、違う言語の基礎の基礎から学ぶと遠回りになってしまうこともあります。
# ======================================
#
# ======================================
# AIに漠然と興味があったら
#
# まず
#
# •AIで何をしたいのか明確にする
#
# •AIの用語を調べてそこからアプローチする
#
# ↓
# 例
# •機械学習で情報を整理したい
#
# •未来の予測をしてみたい
#
# ↓
# 絞ると環境から実行までの書籍が見えてきます。
#
# https://twitter.com/yamazo1111/status/1096988900092858373?s=21 …
# ======================================
#
# ======================================
# GoogleマップのARナビ機能、ストリートビューのデータや機械学習の活用を解説 - Engadget 日本版 https://japanese.engadget.com/2019/02/13/google-ar/ … #navigation #map #AR #ML
# ======================================
#
# ======================================
# 特徴選択とは？機械学習の予測精度を改善させる必殺技「特徴選択」を理解しよう https://www.codexa.net/feature-selection-methods/ …
# ======================================
#
# ======================================
# 機械学習上級者は皆使ってる？！アンサンブル学習の仕組みと3つの種類について解説します https://www.codexa.net/what-is-ensemble-learning/ …
# ======================================
#
# ======================================
# だいたい一般人の解釈がこれなので、職場で説明するときも修正がめんどくさいので機械学習とだけ言ってる
# ======================================
#
# ======================================
# 数理学部の同期が、機械学習全然分からんけど、式見て理解していってるのマジですごいって思った 呪文にしか見えない
# ======================================
#
# ======================================
# †AIと呼ばれる機械学習（ディープラーニング）†
# ======================================
#
# ======================================
# いろいろあって機械学習を使いこなす必要が出てきたので(震え声)もちろん知ったのは最近で、数ヵ月前まで｢ぴちょん｣って読みだと思ってた。
# ======================================
#
# ======================================
# 対話型UIってどれくらい使われているだろう？
# 個人的には面倒で使わないんだけど世間での活用状態が気になる。
# ======================================
#
# ======================================
# 世界最大規模の機械学習コンペティション「Kaggle」に熱中する「Kaggler」と呼ばれる人々とは【デブサミ2018 夏】 (Codezine) #NewsPickshttps://codezine.jp/article/detail/11066 …
# ======================================
#
# ======================================
# まーたGAN使って面白いことやってるー 2次元系と機械学習の話好きだからどんどん出てきて欲しい
# ======================================
#
# ======================================
# なるほど！！
# この本ジャルダン標準形まで詳しく載っているのでいいと思います！
#
# そして、機械学習エンジニア採用中です笑笑
# ======================================
#
# ======================================
# SoftwareDesignの機械学習ムック、ソースコード付いてるのかな？
# 実際に動くものを公開したほうがいいと思うんだけど。
# ======================================
#
# ======================================
# 社内で機械学習講座やった時の事だが、技術職だけどΣって何だっけ？って方もぼちぼちいる。微分積分、FFTもちゃんと説明できる人とそうでない人がいる。確かに知らなくても仕事にはなるが・・・。自主的に勉強させるのは難しいので、小規模に失敗させるしかないんだろうな。
# ======================================
#
# ======================================
# お兄さん機械学習楽しくてVRChat入れないわ。
# 納得できるものができたらインするわ。(フラグ
# ======================================
#
# ======================================
# ジレットのカミソリが「替え刃2本付き！」って書いてあるのに、本体にセットされている刃と替え刃が1本しか付いてなくて、これがエレベータの階数のように日本語と外国語の概念の違いによるものなのか、俺の日本語能力がおかしいのか判断できない
#
# そして、こんなことが週に何度も起きている
# ======================================
#
# ======================================
# 『決定木ベースの機械学習モデル(Random Forests, XGBboost)からdefragTreesを利用して一目でわかるルールの抽出を試みる。 - Qiita』サイバー セキュリティ リスク (CS…｜http://www.cyber-security-risk.info/article/464184821.html …
# ======================================
#
# ======================================
# 戦争が一番わかりやすいけれど、高機能な機体や優れた戦士は希少で数の暴力の前には無力だったのだけれど、お金の力で希少な戦力を大量に集めることこそが一番になりつつありますね
# ======================================
#
# ======================================
# 入力履歴残してこの曜日これよく食いたがるよとか作り始めたらいよいよ機械学習じゃん 3ヶ月くらい休みくれ
# ======================================
#
# ======================================
# 機械学習システムのアーキテクチャアラカルト https://www.slideshare.net/BrainPad/ss-131876455 …
# ======================================
#
# ======================================
# なるほどです！機械学習/deep learning系に久々に手をつけようと思っているので、その辺の論文に出てくる数式がさらっと理解できるようにブラッシュアップすることを想定しておりました。
# ======================================
#
# ======================================
# 今はまずフレームワークやライブラリありきでプログラミングを始める人が多いと思うので、それらを勉強して使えるようになって、その内ハマったりトラブったりで「根底にある知識が足りないな？」と気づくと思うので、そうしたらコンピュータ科学を徐々に覚えるのが王道なのでは
#
# 逆からの人は希少種
# ======================================
#
# ======================================
# 色々あって西尾泰和さんの「If文から機械学習への道」を見た、勉強になる＆自分の機械学習への認識の確からしさを確認できた。機械学習≒アルバイトより、機械学習≒新入社員と言った方が私の周りには理解されそう。（アルバイトの具体的イメージがない人が多い・・・）
# https://www.slideshare.net/nishio/if-80195170?ref=https://cybozushiki.cybozu.co.jp/articles/m001358.html …
# ======================================
#
# ======================================
# このサイト楽しい
# 再読み込みするたびに「存在しない人の顔」が表示される
# (機械学習GANにより生成されてる)
# https://thispersondoesnotexist.com/
# ======================================
#
# ======================================
# #ipa未踏
# #未踏DemoDay
# もしかして機械学習とロボットの制御ってものすごく相性がいいのかな？？
# 発表を見ていたらそんなことを思った休日の昼。
# ======================================
#
# ======================================
# MITが開発の自動機械学習システム、仕事効率はデータサイエンティストの100倍速オーバー！ | Techable(テッカブル)
# https://www.techable.jp/archives/69273
# ======================================
#
# ======================================
# なんか追加で入れるのでしたっけ？
# Flash使うことがなさ過ぎて忘れました…
# ======================================
#
# ======================================
# 揃わないと赤でるなら事前に徴収すべき。出席率もあがるし。
# 当日スムーズに運営するために事前に集金します、とか言えば角が立たないのでオススメ。
# 今はkyashとかlinepayみたいな送金手段もあるし簡単。
# ======================================
#
# ======================================
# レイヤー関係なく人を集めるときは全員揃うと思わないほうがいい。
# 期待しないで揃ったらラッキーくらいの気持ちの方が安全。https://twitter.com/41031ra131/status/1096734717418790912 …
# ======================================
#
# ======================================
# 「機械学習をしなくて良い方法を考える」は、そうだな、と.
# 「技術的負債が蓄積しやすい」も、まさに！と思うので、これはチームで考えていくべきだな. 世の中はみんなどうやってるんだろう.
# ======================================
#
# ======================================
# 「仕事ではじめる機械学習」の目次を眺めた時に、今まで頭の中で考えていたことをまとめているように感じたので丁寧に読んでいこうと思います.
# まずは第1章
# ======================================
#
# ======================================
# 今から機械学習するかAkkaするかDDDするかそれが問題だ。
# ======================================
#
# ======================================
# 人工知能の特許の勘所とは？
#
# 企業経営者が知るべき特許戦略http://bit.ly/2UAsNg0
# ======================================
#
# ======================================
# 今現在Flashが使えるブラウザ(Windows or Linux)ってどれだ…
# どうしてもログインしなきゃいけないサイトがあるんだけどトップページがFlashで積んでる
# ======================================
#
# ======================================
# " #アルゴリズム は、自身が動作する環境に対する事前知識なしで、お互いにコミュニケーションをとることもなく、談合するように特に設計されたわけでも指示されたわけでもなく、純粋に試行錯誤によって #談合 を学びました"
# #AI #機械学習 #強化学習https://www.technologyreview.jp/nl/pricing-algorithms-can-learn-to-collude-with-each-other-to-raise-prices/ …
# ======================================
#
# ======================================
# #ipa未踏
# #未踏DemoDay
# 「学習をかけてスムーズな動きになるようにする」機械学習を使うとこんなこともできるようになるのか。
# すばらしいな。
# ======================================
#
# ======================================
# 【おすすめ：人工知能 】「Python機械学習プログラミング」 Pythonとライブラリを用いて、機械学習の「理論と実践」を習得できる。 http://amzn.to/2mWgyMN
# ======================================
#
# ======================================
# 勝てそうな人選んでるあたりなんだかなーって思ったりしますねー
# ======================================
#
# ======================================
# 【動画あり】ＡＩが製品の組み立て作業を指導する時代に - ニュースイッチ Newswitch
# https://newswitch.jp/p/16522  #人工知能 #機械学習 #AI
# ======================================
#
# ======================================
# 明日発売の「ソフトウェアデザイン 2019年3月号」…書いた記事は「手持ち動画撮影からのライトフィールド画像処理による自由視点生成処理」で、本号の特集は（1月号の線形代数と機械学習みたいな）微分と機械学習の話。…これは売り切れそうな内容かも。
# https://amzn.to/2IimcF8 pic.twitter.com/EQmO0EytFE
# ======================================
#
# ======================================
# matlabの画像の機械学習はやっぱりcpuだと無理があるんですかね…
# ======================================
#
# ======================================
# しかしまあ、機械学習初歩の初歩、AzureでdarknetでDLハンズオン最終日！みたいなのを、自前でやってる程度の話だが…この程度でも、時間もお金もそれなりにかかるわね。継続的にやるなら、予算切ってもらう必要はあるだろうなあ。そりゃそうさあ。
# ======================================
#
# ======================================
# 金沢工大、全学部で「AI基礎」を必修化。機械学習などを学び研究力のある技術者を育成へ http://fanblogs.jp/25hello/
# ======================================
#
# ======================================
# 僕の機械学習プログラム第1号「東方えっちイラスト選別プログラム」
# ======================================
#
# ======================================
# ついった上の画像を収集して機械学習させて、東方かつえっちいイラストだけを選別するアルゴリズム作りそう。
# ======================================
#
# ======================================
# スマートフォンアプリ、脳くらげは、機械学習をわかりやすく示している推測ゲームです。ぜひお試しください！　Android版対応→→http://shannon-lab.org/?page_id=4416 　iphone版→→https://itunes.apple.com/ca/app/naokurage/id993206570 …
# ======================================
#
# ======================================
# AWS SageMakerとAPI Gateway、Lambdaで作るサーバレスな機械学習アプリケーション - Qiita
#
# https://qiita.com/kurakura0916/items/5d6e9254e5c654e098a7 …
# ======================================
#
# ======================================
# レコード会社インターンシップを募集
# 企画営業・マーケティング / 機械学習開発プログラマ / A&R・マネジメント / 制作宣伝職を募集中!!
# http://evening-mashup.com/music-intern
# いいね!!と思ったらシェアしよう
# #音楽
# #music
# #エンターテインメント
# #EVENING
# #EveningMusicRecords
# #拡散希望
# ======================================
#
# ======================================
# AWS SageMakerとAPI Gateway、Lambdaで作るサーバレスな機械学習アプリケーション - Qiita http://bit.ly/2TQDpqh
# ======================================
#
# ======================================
# 平日・休日問わずオフィスに出勤していたのですが、休日はオフィスではなく、場所を変えて作業するほうが効率良さそうだと実感。都内周辺のオススメ作業スペースある方ぜひ教えてください！
# ======================================
#
# ======================================
# 僕もとても良いと思いました
# ======================================
#
# ======================================
# 【Udemy】みんなのAI講座 ゼロからPythonで学ぶ人工知能と機械学習
# 初心者向けの人工知能と機械学習のコースです。プログラミング言語Pythonを使って、機械学習とプログラミングの基礎、必要な数学を勉強しましょう！
# https://www.udemy.com/learning-ai/?deal_code=JPA8DEAL2PERCENTAGE&aEightID=s00000016735001 …
# ======================================
#
# ======================================
# まあカーネルも機械学習だしねぇ...
# ======================================
#
# ======================================
# unity ml-agents-tool-kitのサンプルシーンを機械学習中。
# 20分ぐらいで15万ステップ学習した状態でこれ。
#
# 学習開始時よりは進むようになってきました。自分のモデルデータも動かしてみたいと感じたこのごろです。
# 強化学習に時間がかかることを実感しました。
#
# #Unitypic.twitter.com/zX1s4kyygh
# ======================================
#
# ======================================
# 写真1枚の画像は、
#  スーラの点描画と同じ
#
#  ドットの集まり。
#
#  写真画像を　手続きなしで
#  ｘｙ座標平面に描き移（うつ）すのが
#  従来の理論物理学者達。
#
#  だが、推論機能のＡＩなら、
#  人工知能。機械学習なら、どうするか。 pic.twitter.com/OTXplMpKha
# ======================================
#
# ======================================
# 実際機械学習系は士業の書く文章の効率化にはとても長けているんだろうなあとおもいつつ。
# ======================================
#
# ======================================
# 京都工芸繊維大学って凄い大学なの…？
#
# いや、酷い大学という意識も何もなくスルーしてたけど
#
# 東工大や会津大の他に名前で騙されてはいけない凄い大学リストください…
#
# 弊社の場合、出身大学で面接結果はまず変わらないけれども
# ======================================
#
# ======================================
# 杉本 徹 の Javaで学ぶ自然言語処理と機械学習 を Amazon でチェック！ https://amzn.to/2V6syZN  @さんから
# ======================================
#
# ======================================
# 長男が不登校なので中学校以降どうなるのか不安
#
# かならずしも進学じゃなくて良いけれど普通の高校はもう無理だろうし
#
# 情緒面はアレだけど、能力に問題があるわけではないので、というか優れているくらいなので伸ばしてあげたいけれど、無限にお金が湧くわけでもないのでどこにでも行かせられ文字数
# ======================================
#
# ======================================
# 身近なところで、働いている人の仕事を楽にするところから成果だしできると素敵ですね。
#
# 例えば需要予測でベテラン分析精度と同レベルを担保できれば、その人は他の仕事に注力できて、短期的にペイできそうだと感じました。
#
# 機械学習が皆の仕事を前向きにサポートするツールになることを希望します。
# ======================================
#
# ======================================
# >原理としての)Fの最小化->(ひとつの方策としての)予測符号化-
# まさにそうだと思います、私も昔から逆に行っていて苦労しました。だとすると、機械学習の人たちは大昔からFをL（Lower bound)と言ってきた歴史がありますが...。
# ======================================
#
# ======================================
# 長女がこの子のことを「饅頭小僧」と呼ぶ
#
# だがこれはカステラだpic.twitter.com/BQXRnpZQNA
# ======================================
#
# ======================================
# 機械学習なんも分からん、引退します
# ======================================
#
# ======================================
# 機械学習で脳波の状態からてんかん発作を検出｜ https://ai-scholar.tech/2019/02/15/brain-ai-77/ …
# ======================================
#
# ======================================
# 声色を全く別人に変えるという意味では機械学習によって作ったフィルタは有効そうだったけど、ときどき言葉の子音とかが失われたりしていて、まだ課題も多そうだった。よい学習データがあるとどれくらい改善するものなのだろうか？ボイスロイドの知見とか生かしたりしたらどうなるだろうか？
# ======================================
#
# ======================================
# 最近少しだけ紅茶に凝っていてLUPICIAというお店のを買ってるんだけど、妻が好きだというLady Grayという紅茶を飲んでみたらとても美味しかった
#
# ちょっと俺、セレブっぽいhttps://www.twinings-tea.jp/sp/products/lady-grey.html …
# ======================================
#
# ======================================
# あなたの耳は「老人耳」、「中年耳」、「若者耳」？http://bit.ly/2QK1Wz9
# ======================================
#
# ======================================
# カスハラ(カスタマーハラスメント)って言葉があるのね。店員に土下座とかさせようとする輩は二郎の店員にも同じこと(やれるもんなら)やってほしい。
# ======================================
#
# ======================================
# 昨日は恋声のパラメータ調整をしていたりした。とりあえず自分は恋声の啓示を受けた民ではないことは確認した。
# 機械学習でフィルタ作る試みもいくつかあることも確認した。
# ======================================
#
# ======================================
# 何十枚か見てみたけどこれはすごいな…加工ってわかるものもあるけどかなり自然なバランスだわ→「全て機械学習アルゴリズムが生成」 この世界に存在しない人物の画像をワンタッチで簡単に生成できる「This person does not exist」 - GIGAZINE
# https://gigazine.net/news/20190217-this-person-does-not-exist/ …
# ======================================
#
# ======================================
# 100ページ以上の強化学習の資料が公開（日本語）
# 強化学習について分かりやすくまとめられています。
#
# 《対象読者》
# ・強化学習について知らない
# ・機械学習に興味がある
# ・生物学の分野出身でモデル生成の行動に興味がある
# ・ゲームを AI に解かせたい
#
# @komi_edtr_1230
# https://github.com/komi1230/Resume/tree/master/book_reinforcement …pic.twitter.com/pEmDu2nwR5
# ======================================
#
# ======================================
# 写真1枚の画像は、
#  スーラの点描画と同じ
#
#  ドットの集まり。
#
#  写真画像を　手続きなしで
#  ｘｙ座標平面に描き移（うつ）すのが
#  従来の理論物理学者達。
#
#  だが、推論機能のＡＩなら、
#  人工知能。機械学習なら、どうするか。 pic.twitter.com/GPjqTR8i5N
# ======================================
#
# ======================================
# 紅茶ってセイロンとかアールグレイとかあるけど、品種としてのお茶の種類がそんなにあるのですかね？製法や入ってるハーブ、もしくは産地や農園を表すブランド名なのですかね？
#
# コーヒーも同じで、コーヒー豆の品種に数十種類もあるとは思えないのですよね
#
# 日本の果物や米は品種改良してるけど
# ======================================
#
# ======================================
# 試行錯誤の末に築かれた標準アーキテクチャとそれらの選択手順、そのように感じる。 / “機械学習システムのアーキテクチャアラカルト” http://htn.to/wfzvet
# ======================================
#
# ======================================
# 「より良い機械学習の手法」に興味のある人達と「流行りの・最新の機械学習プラットフォームを使う」ことに興味のある・あるいはそれで精一杯の人たち、そして「機械学習を使えば何かいい感じにできるんでしょ」という人たちのそれぞれの間の溝、という感じかなぁ。 https://twitter.com/TJO_datasci/status/1096798343521390593 …
# ======================================
#
# ======================================
# と言うか昔からそうだけど脳のない経営陣はコンサルの美味しい餌だよね、でコンサルの今のトレンドが機械学習とかそういう関連なだけで
# ======================================
#
# ======================================
# TechAcademyでPythonコースを受けた。色々指導してもらい、paizaでBランクが出来るレベルへ。
# まだまだライブラリとか全然やけど、少し出来る感じになった。
# 次はAIコースで本格的に機械学習を学ぶ。で、仕事に使う。
# みんながやらない事をやる。それが価値になる。そう信じている。
# ======================================
#
# ======================================
# パスポート取れて幸せだから、機械学習システムを使いやすくするためにGUI構築しよう！
# ======================================
#
# ======================================
# デブサミ 、去年(初参加)の感想を乱暴にまとめると、
# 「機械学習すげー」でした。
# 今年は
# 「『自立して自分で責任取って楽しくやろう』をみんな言ってる気がするなー」でした。
# ======================================
#
# ======================================
# 糖尿病薬の処方、間違ってませんか？AIでHbA1c値「7・0％未満」へ - ニュースイッチ Newswitch
# https://newswitch.jp/p/16518  #人工知能 #機械学習 #AI
# ======================================
#
# ======================================
# 金沢工大、全学部で「AI基礎」を必修化。機械学習などを学び研究力のある技術者を育成へ http://fanblogs.jp/25hello/
# ======================================
#
# ======================================
# 経営者世代は全然パソコン詳しくないくせに機械学習を取り入れようとする日本経営界の闇
# ======================================
#
# ======================================
# 東京大学工学教程 機械学習
# ある程度線形代数と微積ができる必要がある機械学習の本。基礎的なことが書いてあり時代の流行り廃りに寄らない知識が手に入るのではないかと今ちびちび読んでいる。
# ======================================
#
# ======================================
# 長女が自分で選んだ卒業式の服可愛いpic.twitter.com/xf5qjgKSgD
# ======================================
#
# ======================================
# 黒柳 敬一 の やってみよう！ 機械学習 (Software Design別冊) を Amazon でチェック！ https://amzn.to/2V4f3JN  @さんから
# ======================================
#
# ======================================
# 持橋 大地 の ガウス過程と機械学習 (機械学習プロフェッショナルシリーズ) を Amazon でチェック！ https://amzn.to/2V312w5  via @
# ======================================
#
# ======================================
# これはなかなか参考になる本。AIを担当するエンジニアはGoogleだと年収7000万円等。北米でも英でも最も需要の高い分野の一つで高報酬でスキルがあれば海外への転職も夢ではありません→機械学習エンジニアになりたい人のための本 AIを天職にするhttp://amzn.to/2WS6bZv
# ======================================
#
# ======================================
# GANの生成する精度が本物と見分けがつかなくなってきた。機械学習に期待されてた人間の単純作業の自動化への寄与ではなく、人間のクリエイティブな部分から潰しにかかるの最高にAIって感じで好きよ
# ======================================
#
# ======================================
# 最近TLに流れる機械学習で画像いじるやつ見ると自動ペン入れ機能もそう遠くない未来にできそうだなと思う
# ======================================
#
# ======================================
# 【Paiza1ヶ月レビュー】
# 【良い点】
# ・1ページ内に，動画説明＋テキストエディタ+コードの説明が入っており，UIが非常に良い．
# ・安い980円/月
# ・Pythonでのwebサービス構築教材が充実．
#
# 【改善希望】
# ・機械学習教材の充実
#
# #paiza
# #100DaysOfCode
# #駆け出しエンジニアと繋がりたい
# ======================================
#
# ======================================
# 学習が足りませんなぁ(機械学習的発想)
# ======================================
#
# ======================================
# 企業の現場でもＡＩの実用事例が増えている
#
# 機械学習に適したデータか？
#
# 問題解決の手段はＡＩ以外でも十分ではないか？
#
# 人や組織とＡＩが融合し最適化できるか？
#
# またＡＩビジネスにかかわる法的リスクとは…
#
# 基本をおさえてビジネスに効くＡＩに触れてみよう
# https://amzn.to/2PnbuAg
# ======================================
#
# ======================================
# 金沢工大、全学部で「AI基礎」を必修化。機械学習などを学び研究力のある技術者を育成へ http://fanblogs.jp/25hello/
# ======================================
#
# ======================================
# うーん、AIが機械学習で5秒で書いた小説でも面白ければ普通に感動するだろうなぁ。別に感動した時に「ああ、これは作者の○○さんの想いや実体験が結実してるんだなぁ」なんていちいち考えないし… https://twitter.com/souzouryoku5/status/1096384956828274688 …
# ======================================
#
# ======================================
# 全てのプロダクトマネージャーが知っておくべき５つの機械学習の限界と対策 – 未来の仕事 – Medium (Medium) #NewsPickshttps://npx.me/12erm/6mwZ?from=twitter …
# ======================================
#
# ======================================
# 「スマホ内の地図画像とストリートビューを一致させるには、変化する一時的な部分を除外し、時間の経過とともに変化しない永続的な構造に焦点を合わせる」
#
# GoogleマップのARナビ機能、ストリートビューのデータや機械学習の活用を解説 - Engadget 日本版 https://japanese.engadget.com/2019/02/13/google-ar/ …
# ======================================
#
# ======================================
# 中国サイトで買ったスマホが「HK,Hand over to airline.」って言いながら絶対船便でそろそろ1カ月なのに届いてないpic.twitter.com/ae0u5C0f56
# ======================================
#
# ======================================
# 大きく認知させることより、小さく深く認知させる流れはオフラインにはあったんだけどオンラインでこれができるのはAI、機械学習の圧倒的勝利
# ======================================
#
# ======================================
# 機械学習でできたのなら数多の人間の集合知だからそれはそれで
# ======================================
#
# ======================================
# 今はWeb系で動的型付け言語やってて、この後は静的型付け言語やった後は機械学習系やりたいな。それに付随する数学、特に統計勉強したい。他に必要なのは会計と法律かな。
# ======================================
#
# ======================================
# 「機械学習オンリーで作られた書籍」っていう事実そのものが素晴らしい物語として読めてしまいますよね…。
# ======================================
#
# ======================================
# 『AI領域でキャリアを積みたい人の機械学習学び方入門』に申し込みました！
# https://techplay.jp/event/715534?utm_source=event_join_save&utm_medium=social&utm_campaign=feed&utm_content=tw1091983380802002945 …
# #techplayjp
# ======================================
#
# ======================================
# 【#機械学習 #年初】人は、記録をつけると、行動が変わる。継続できる。人生が変わる。 | Books&Apps なるほどね。http://bit.ly/2HGtdz5 https://blog.tinect.jp/?p=55604
# ======================================
#
# ======================================
# 機械学習で、考えるとは何かを試行錯誤するとかしてなんか生み出せないかな
# ======================================
#
# ======================================
# 機械学習で感動できる物語できてたらその事実に感動しない？？？
# ======================================
#
# ======================================
# 検査結果やカルテ、手書きの診断書などを学習して、子どもの病気を医師と変わらない精度で診断できる人工知能（ＡＩ）プログラムの開発に成功したと、中国や米国の研究者らのチームが発表した。
#
# #医療 #機械学習
# https://www.jiji.com/jc/article?k=20190213038239a&g=afp …
# ======================================
#
# ======================================
# 全てのプロダクトマネージャーが知っておくべき５つの機械学習の限界と対策 – 未来の仕事 – Medium (Medium) #NewsPicks https://npx.me/12erm/n6xE?from=twitter …
# ======================================
#
# ======================================
# 「関西」のことを「監査委」と書いてしまったのはATOK(日本語変換ソフト)です
#
# 重ね重ねお詫びを申し上げます
# ======================================
#
# ======================================
# 監査委の皆さんごめんなさい
#
# また僕は「関西学院」を「かんさいがくいん」と読んでしまいました
# ======================================
#
# ======================================
# 機械学習によるメモリアクセス予測：Learning Memory Access Patterns http://rviv.ly/cZLknz
# ======================================
#
# ======================================
# 03/19(火) [参加125人/定員100人]http://bit.ly/2GpvGwt 【Mix Leap Study #37 - 世界の最先端量子コンピュータ技術と機械学習】 #mixleap
# ======================================
#
# ======================================
# 03/23(土) [新着][人気上昇中][参加10人/定員24人]http://bit.ly/2NawHcl 【機械学習名古屋　第19回後　懇親会】
# ======================================
#
# ======================================
# そういえば、蜘蛛の糸、タンパク質な糸の製品化のスパイバーや体液の微量な高分子の分析とその機械学習などのデータ分析で病気の早期検出などやってる、山形県はどうなったのかしら。そろそろ十年だと思うけど
# ======================================
#
# ======================================
# 耳の年齢を調べてみましょう。
# あなたの耳は「老人耳」、「中年耳」、「若者耳」？http://bit.ly/2QK1Wz9
# ======================================
#
# ======================================
# どらやきは おいしいなぁ
#
# この文章はドラえもん(AI)が機械学習によって5秒で作成しました。作者(ドラえもんの開発者)の想い、作者の実体験などは何もありません
# ======================================
#
# ======================================
# [新着] 2019/03/16（土） 【基礎数学】機械学習・ディープラーニングのための確率・統計 DAY1 https://goo.gl/HmfBZx
# ======================================
#
# ======================================
# 機械学習やりたいな
# ======================================
#
# ======================================
# フーリエ変換とかポアソン分布基礎理論だけどエンジニア業界で十分使われるのでは…
#
# そういうジャンルをやってないだけで…
# 近年の機械学習とかの流行で逆にフーリエ変換とか画像解析で使うんじゃないの？
# ======================================
#
# ======================================
# とりあえず今日はのんびり機械学習の講義資料見ながら午後は情処申し込みとかかな
# ======================================
#
# ======================================
# 気にする人は気にしたらいいと思う。
# ワシはなんなら機械学習で作られた小説読みたいまであるけど
# ======================================
#
# ======================================
# 機械学習によって平滑化された世界
# #エントロピーと彫刻
# ======================================
#
# ======================================
# 機械学習によって作られたものが最高に魂籠っててツボなら何一つ文句はないよ（ ˘ω˘ ）
# ======================================
#
# ======================================
# AIが機械学習したなら学習元のデータがあるのでは？？？？
# ======================================
#
# ======================================
# 【おすすめ：人工知能 】「ITエンジニアのための機械学習理論入門」  http://amzn.to/2mhIZkb
# ======================================
#
# ======================================
# セキリュティかデータベースか、機械学習か悩むのう
#
# まあ、ひと通りかじってから決めればいいか
# ======================================
#
# ======================================
# 「積み重ねのパターンや膜の厚さが異なる80億通りもの候補の中から最適な構造を見つけた。その際、シミュレーションや機械学習を活用したAI技術を使った。」材料開発にAI革命：日本経済新聞 https://www.nikkei.com/article/DGKKZO41320220V10C19A2MY1000/ …
# ======================================
#
# ======================================
# 現在開発中の新しいRELEASEでは、機械学習や深層学習、AI（人工知能）技術を用いて、最適な情報を探し出し、ユーザーへ価値ある情報を提供します。
#
# 比較的簡単な情報検索には機械学習を適用し、機械学習では対応しきれない複雑な情報検索に対しては深層学習を適用します。
#
# https://release.co.jp/white-paper/ja/ pic.twitter.com/PiTgSRIh2b
# ======================================
#
# ======================================
# 子どもの成長は機械学習の観点から見ても面白い。２歳にもなると姿勢制御も安定してきて、１００クラス分類はできるようになるし、簡単な発話生成モデルができ、スーパーマリオもたまに最初のクリボーを飛び越えることもできる。複雑な環境から本質的な情報を抽出して一生懸命学んでいる。
# ======================================
#
# ======================================
# ◇2月17日のTo Do
# ○機械学習（AI）学習
# ○ストレッチ筋トレ
# ○つくりたいもの考える
# ○英語を聴く
# ○気が向いたら、散歩
#
# のんびり、ゆったり系ですな。
# でも、ガツガツ勉強していきます。
# とりあえず早起きしないとなー。
# ======================================
#
# ======================================
# 本日2019年02月17日の大当たり回数予想です！ - あらやだ、写ってる(^^;
# #パチスロ #機械学習 #ビックマーチ藤代 https://www.fantasista.site/rank/slot/141010/ …
# ======================================
#
# ======================================
# 機械が現実を理解するには現実をデジタル化するしかない。(機械学習)
# ======================================
#
# ======================================
# https://www.yoheim.net/blog.php?q=20160507 …
# ======================================
#
# ======================================
# 機械学習やるか
# ======================================
#
# ======================================
# 機械学習のフリーランス案件相場。
# Python実務未経験でも簡単なプライベートプロジェクトかサンプル持っていけば参画できるっぽいんだよな。 https://twitter.com/freelancestart1/status/1096907198775611393 …
# ======================================
#
# ======================================
# 機械学習名古屋　第19回後　懇親会 に参加を申し込みました！ https://machine-learning.connpass.com/event/121160/?utm_campaign=event_participate_to_follower&utm_medium=twitter&utm_source=notifications …
# ======================================
#
# ======================================
# https://qiita.com/riverwell/items/c8f1d4d476d3bf0da005 …
# ======================================
#
# ======================================
# AIを使うのはめちゃ地道。苦労がよくわかる記事
#
# "現在は目視で行っている生育不良の個体を取り除く作業においても、画像解析と機械学習を組み合わせて自動化することを目指すという。"
#
# 「近大マダイ」の養殖にマイクロソフトのAIを活用　近畿大学水産研究所の現場レポートhttps://cloud.watch.impress.co.jp/docs/column/ohkawara/1169719.html …
# ======================================
#
# ======================================
# https://qiita.com/uezo/items/0c92ba960a6a47b14921 …
# ======================================
#
# ======================================
# 確かに、時系列の解析は大変だけど、画像に直してしまえば解析可能に。発想の転換やな
#
# 機械学習で脳波の状態からてんかん発作を検出｜ https://ai-scholar.tech/2019/02/15/brain-ai-77/ …
# ======================================
#
# ======================================
# 機械学習名古屋　第19回後　懇親会に参加を申し込みました！ https://machine-learning.connpass.com/event/121160/?utm_campaign=event_participate_to_follower&utm_medium=twitter&utm_source=notifications …
# ======================================
#
# ======================================
# 現在Skype工学勉強会では新設のセミナーの企画を募集しています。
#  一例としては
# ・材料力学
# ・数理工学
# ・機械学習
# ・制御工学
# などです。企画立案に関する相談は気軽にリプライをください。
# ======================================
#
# ======================================
# デザインプロセスの研究というのは、具体的には何を目的としているかというと、機械学習でデザインの要素をあぶり出し取捨選択でデザインを可能にすること。デザイナーの個性をデータ化すること。デザイナーのAIクローンを作ること。
# ======================================
#
# ======================================
# 言語化の難しい業務を最適化するのに機械学習は有効です。しかし、入出力の期待値が明確でない場合、学習自体が困難となります。
# #RPA
# ======================================
#
# ======================================
# 経営者が知るべき人工知能が生むビジネスチャンスを つかむための戦略とは？
# http://bit.ly/2baT1kD
# #AI #人工知能 #IoT #機械学習
# ======================================
#
# ======================================
# 子どもの才能を引き出す最高の学びプログラミング教育
# https://amzn.to/2RPPoTJ
#
# 「２０４５年には、人工知能が人類の知能を超える転換点『シンギュラリティ』に到達する」
# ――レイ・カーツワイル(Google社機械学習・自然言語処理技術責任者)
#
# 必要なのは「論理的思考力」
# ======================================
#
# ======================================
# まさしくこれです。例えばある食べ物の成分分析してさ、それをちょこっと機械学習したら色々わかるんじゃないの。ってよく言われますが、で、何を知りたいのですかって。 https://twitter.com/TJO_datasci/status/1096796657989996545 …
# ======================================
#
# ======================================
# 機械学習に冷め始めている自分がいる。。。
# ======================================
#
# ======================================
# 2019年2月
# 機械学習エンジニア求人・案件の月額単価相場情報
# 最高単価：162万円
# 平均単価：78.7万円
# より詳細な分析はこちらから↓
# https://freelance-start.com/jobs/job_category-16 …
# #フリーランススタート #エンジニア #機械学習エンジニア #MachineLearning #先端技術 #案件相場 #フリーランス #FREELANCE STARTpic.twitter.com/GCtvP2HEkW
# ======================================
#
# ======================================
# 【人工知能はどのようにして 「名人」を超えたのか?―――最強の将棋AIポナンザの開発者が教える機械学習・深層学習・強化学習の本質/山本 一成】を読んだ本に追加 → https://bookmeter.com/books/11810240  #bookmeter
# ======================================
#
# ======================================
# 金沢工大、全学部で「AI基礎」を必修化。機械学習などを学び研究力のある技術者を育成へ http://fanblogs.jp/25hello/
# ======================================
#
# ======================================
# 機械学習関連の開発プロジェクトを立ち上げるべく勉強中
# ======================================
#
# ======================================
# Google の講演資料。機械学習で分類する際のアルゴリズムについて、わかりやすい。ニューラルネットワークだと非線形となる。 pic.twitter.com/oOMk47yjad
# ======================================
#
# ======================================
# 金沢工大、全学部で「AI基礎」を必修化。機械学習などを学び研究力のある技術者を育成へ http://fanblogs.jp/25hello/
# ======================================
#
# ======================================
# 機械学習といっても応用も理論もあるし分野広いしやることが山ほどあるし難しいですが、convex opt、stochastic processes、inference全般、pro・・・
# 続きは質問箱へ
#
# #peing #質問箱https://peing.net/ja/qs/143242342
# ======================================
#
# ======================================
# こちらこそ ありがとうございます。
# 元々Unity勉強したくて、TECH::MASTER始めたんですが、今月末でコースが終わるので、最近はAIの機械学習ばかりやってます。
# オンラインはモチベーションの維持が結構つらいですが、自分のためなんで頑張ってます。
# 楽しく学習して、楽しく働けたらいいですよね！
# ======================================
#
# ======================================
# 企業経営者が知るべき人工知能戦略とは？
# http://bit.ly/2c1bP5V
# #AI #人工知能 #IoT #機械学習
# ======================================
#
# ======================================
# ついに完成！
#
# まあ教本が一通り終わったってだけで理想には程遠い出来ですが、、
#
# まだしっかりした会話にはならないし、画像じゃなく動画にしたいしなんならVRにしたい
#
# 道のりは長い
#
# #人工知能
# #対話bot
# #Python
# #AI
# #機械学習 pic.twitter.com/369BuEM6OG
# ======================================
#
# ======================================
# 最小二乗法（実装編） - 波動と機械学習 https://araitbs007.hatenablog.com/entry/2019/02/17/061922 …
# 新しい記事をアップしました！
# やりたいことが本格的にスタートした感じです。
# 皆さんも機械学習始めてみませんか？？
# ======================================
#
# ======================================
# 「エンジニアなら知っておきたいAIのキホン機械学習・統計学・アルゴリズムをやさしく解説」の人気が上昇中（2日連続） https://sciengbook.nekast.com/2019/01/26/post-5058/ …
# ======================================
#
# ======================================
# 機械学習、ディープラーニング、PythonAIについて興味がある方はぜひ利用してみてください。  ★特徴★ ・低価格 ・経験豊富なエンジニアが回答してくれる  Python学習サービスPyQ（パイキュー）の口コミ・評判 http://rplay.me/8538
# ======================================
#
# ======================================
# 最後の一文にもあるけど、これそのものの成果も素晴らしいけど、十分な量の数値をAIに食わせられないときに、画像を食わせて何らかのパターンを検出させるっていう方法論の確立の意義がデカイ気がする。AI界隈では既に常識？ - 機械学習で脳波の状態からてんかん発作を検出｜ https://ai-scholar.tech/2019/02/15/brain-ai-77/ …
# ======================================
#
# ======================================
# とりあえず引っ越し終わったら、3月中は研究内容を考えよう
# 機械学習についてやることは決まってるけど、深層学習とか強化学習とか少しは勉強しないと決めれないからねぇ
# ======================================
#
# ======================================
# ふと思ったんですが今までのツイート全部機械学習にかけたらある程度の精度のbotできるかな
# ======================================
#
# ======================================
# pythonでGUI関係の調べ事をしてたら、どうやら html形式で作成可能であることが判明。一応 html, css, java, js はコーディング出来るからもう少し深く調べてみよう(＾ω＾)
#
# [Python] EelをつかってHTML/CSS/JavaScriptでGUIを構築https://qiita.com/inoory/items/f431c581332c8d500a3b …
# ======================================
#
# ======================================
# 一方チェスは人間が苦手なことでそれゆえゲームとして面白く感じるのだと思っているので、人間のプレイを模倣することではなくより正確な手を見つけられるようにするという点では、機械学習を利用したエンジンが有望だとは、私は信じていない。
# ======================================
#
# ======================================
# 最近の機械学習ブームは人間が得意なことを人間と同じくらいかそれ以上に上手くできるというものだと理解している。画像、音声、自然言語などの分野で成果をあげていて、これらは人間の振る舞いを模倣すること自体が目標。
# ======================================
#
# ======================================
# 機械学習のアニメキャラ生成の関連のヤツいろいろ見てたけどすごいな
# ======================================
#
# ======================================
# 03/19(火) [人気上昇中][参加123人/定員100人]http://bit.ly/2GpvGwt 【Mix Leap Study #37 - 世界の最先端量子コンピュータ技術と機械学習】 #mixleap
# ======================================
#
# ======================================
# ゲーミング用でもないノートpcで、推奨スペックを無視したゲーム、機械学習に使ってるから、すぐに壊れそうだな...
# ======================================
#
# ======================================
# 機械学習アプリケーションの本番利用に向けたアプローチ
#
# How to Move from Experimentation to Building Production Machine Learning Applications – https://blogs.oracle.com/ai/how-to-move-from-experimentation-to-building-production-machine-learning-applications … @Oracleさんから
# ======================================

# %% [markdown]
# # データベースを使ってみよう
#
# データベースとはコンピューターを利用して膨大なデータをまとめ、
# 管理されたデータの集まりのことです。
# データベースには複数のテーブルがあります。テーブルとはいくつかの列(カラム)から構成されています。
# <br>
# ![データベースの構造](https://aiacademy.jp/assets/img/db.png)
# <br>
# テーブルには異なる様々なデータが入っており、テーブルには行(レコード)と列(カラム)があります。
# また、データベースは、管理するという視点でExcelよりも容易に管理できます。
# 例えば、データベースはTwitterのようなSNSでは顧客の個人情報や、つぶやきのデータ等もデータベースで管理されています。
# ここでは、数あるデータベースのうち、手軽で使いやすいSQLiteを使ってみます。

# %% [markdown]
# # ハンズオンパートその2
# ## 一緒に手を動かしてみましょう！
# ### まずは、テストでSQLiteをPythonから動かしてみましょう。

# %%
import sqlite3

con = sqlite3.connect("data.db")    # データベースを作成する

# ここで、data.dbが作成されているか、確認してください

cur = con.cursor()    # SQLを実行するために、カーソル（パソコンで言う矢印マーク）作成
cur.execute('create table test (name varchar(10), company varchar(10))')    # テーブルを作成するSQL文を実行
con.commit    # 実行結果をデータベースに反映させる
cur.execute('select * from sqlite_master WHERE type="table"')    # テーブル一覧を表示するSQL文を実行
for item in cur.fetchall():
    print(item)
    
# ここで、testテーブルの情報が出力されましたか？
    
cur.execute("insert into test values ('ishikawa', 'cyberbrain')")    # レコードを入力するSQL文を実行
con.commit()
cur.execute("select * from test") #レコード一覧を表示するSQL文を実行
val = cur.fetchall()
print(val)

# ここで、レコードが出力されましたか？
# Out:
# ('table', 'test', 'test', 2, 'CREATE TABLE test (name varchar(10), company varchar(10))')
# [('ishikawa', 'cyberbrain')]

# %% [markdown]
# # ハンズオンパート
# ## 一緒に手を動かしてみましょう！
# ### Yahoo! Japanのニュースをスクレイピングして、データベースにデータを作成し、表示してみましょう。

# %%
from bs4 import BeautifulSoup as bs
import requests
import lxml
import sqlite3

url = 'https://www.yahoo.co.jp/'    # 取得するWEBページを記載する
r = requests.get(url)    # requestsを使って、WEBページからデータを取得する
soup = bs(r.text, 'lxml')    # lxmlを使って取得したデータを分析する
scraped = soup.find_all("a")    # 分析結果から、タグ名（aタグ）で特定する
for s in scraped[4:12] :    # 特定部分のニュースを抽出
    print(s.text)    # 抽出したニュースのテキストを表示
    print(s.get("href"))    # 抽出したニュースのリンクを表示

con = sqlite3.connect("data.db")    # データベースを作成する

cur = con.cursor()    # SQLを実行するために、カーソル（パソコンで言う矢印マーク）作成
cur.execute('create table news (title varchar(100), link varchar(100))')    # テーブルを作成するSQL文を実行
con.commit()    # 実行結果をデータベースに反映させる
tables = cur.execute("SELECT * FROM sqlite_master WHERE TYPE='table' AND NAME='news'")    # テーブル情報を表示するSQL文を実行
for t in tables:    # テーブル情報を表示
    print(t)

## ここで、newsテーブルの情報が出力されましたか？

for s in scraped[4:12] :    # スクレイピングしたデータはリスト上なので、for文で表示
    s0 = s.text    
    s1 = s.get("href")
    p = "INSERT INTO news(title, link) VALUES(?, ?)" # newsテーブルにデータを作成するSQL文
    cur.execute(p, (s0, s1)) 
    con.commit()

rows = cur.execute("SELECT * FROM news")
for r in rows :
    print(r[0], r[1])
    
# # ここで、レコードが出力されましたか？
# Out:
# 恐怖今も 普天間停止18日期限
# https://news.yahoo.co.jp/pickup/6314156
# ナウアート氏 米国連大使辞退
# https://news.yahoo.co.jp/pickup/6314159
# 落城400年 石の「名城」の今
# https://news.yahoo.co.jp/pickup/6314152
# 隠れた物体 デジカメで可視化
# https://news.yahoo.co.jp/pickup/6314151
# アニメの彩色 AIで自動化開発
# https://news.yahoo.co.jp/pickup/6314160
# ブラシ折れ転倒 藤沢五月苦笑
# https://news.yahoo.co.jp/pickup/6314157
# 乾効果? J選手にスペイン人増
# https://news.yahoo.co.jp/pickup/6314161
# 田原俊彦40年 死ぬ気で走った
# https://news.yahoo.co.jp/pickup/6314153
# ('table', 'news', 'news', 2, 'CREATE TABLE news (title varchar(100), link varchar(100))')
# 恐怖今も 普天間停止18日期限 https://news.yahoo.co.jp/pickup/6314156
# ナウアート氏 米国連大使辞退 https://news.yahoo.co.jp/pickup/6314159
# 落城400年 石の「名城」の今 https://news.yahoo.co.jp/pickup/6314152
# 隠れた物体 デジカメで可視化 https://news.yahoo.co.jp/pickup/6314151
# アニメの彩色 AIで自動化開発 https://news.yahoo.co.jp/pickup/6314160
# ブラシ折れ転倒 藤沢五月苦笑 https://news.yahoo.co.jp/pickup/6314157
# 乾効果? J選手にスペイン人増 https://news.yahoo.co.jp/pickup/6314161
# 田原俊彦40年 死ぬ気で走った https://news.yahoo.co.jp/pickup/6314153
